# %%
# !pip install mysql-connector
# Out:
# Collecting mysql-connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 147.1 kB/s eta 0:00:0000:0100:03
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mysql-connector
#   Building wheel for mysql-connector (setup.py) ... done
#   Created wheel for mysql-connector: filename=mysql_connector-2.2.9-cp311-cp311-linux_x86_64.whl size=247950 sha256=f99357eaf068558e5d56fd0cd6c092dc90345519460491f964e57c262795a0f4
#   Stored in directory: /home/michael/.cache/pip/wheels/17/cd/ed/2d49e9bac69cf09382e4c7cc20a2511202b48324b87db26019
# Successfully built mysql-connector
# Installing collected packages: mysql-connector
# Successfully installed mysql-connector-2.2.9

# %%
import mysql.connector
import pandas as pd

# create a connection to the database
conn = mysql.connector.connect(
	host="localhost",
	user="root",
	password="azer2010",
	database="titanic",
    auth_plugin='mysql_native_password'
)

# %%
query = "SELECT * FROM passenger"
df = pd.read_sql(query, conn)
df
# Out:
# /tmp/ipykernel_122314/1724960500.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# 709               Rice, Mrs. William (Margaret Norton)  female   39      0
# 710                              Montvila, Rev. Juozas    male   27      0
# 711                       Graham, Miss. Margaret Edith  female   19      0
# 712                              Behr, Mr. Karl Howell    male   26      0
# 713                                Dooley, Mr. Patrick    male   32      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500              S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250              S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500              S
# ..     ...               ...      ...   ...      ...
# 709      5            382652  29.1250              Q
# 710      0            211536  13.0000              S
# 711      0            112053  30.0000   B42        S
# 712      0            111369  30.0000  C148        C
# 713      0            370376   7.7500              Q
#
# [714 rows x 12 columns]
